# %% [markdown]
# # Export death
# https://www.covid19.admin.ch/en/overview

# %%
import pandas as pd
import math

# %%
df = pd.read_csv('COVID19Death_geoRegion.csv', encoding='latin-1')
df = df[df.geoRegion != 'FL']
df = df[df.datum >= '2020-03-05']

# %%
df_g = df.groupby('datum').agg({'entries': 'sum'})

# Calc Notes per day
df_g['%'] = df_g['entries'].apply(lambda x: round(100 / 312 *x))

# BarPos
df_g = df_g.reset_index()
df_g = df_g.reset_index()
df_g['b'] = df_g['index'].apply(lambda x: x % 4 + 1)
df_g = df_g.set_index('datum')
df_g = df_g[['b', 'entries', '%']]

df_g['entries'].plot(figsize=(25, 2.5))
# Out:
# <AxesSubplot:xlabel='datum'>

# %%
df_g.head(35)
# Out:
#             b  entries   %
# datum
# 2020-03-05  1        6   2
# 2020-03-06  2        0   0
# 2020-03-07  3        0   0
# 2020-03-08  4        3   1
# 2020-03-09  1        0   0
# 2020-03-10  2        6   2
# 2020-03-11  3        9   3
# 2020-03-12  4       12   4
# 2020-03-13  1        9   3
# 2020-03-14  2       15   5
# 2020-03-15  3       24   8
# 2020-03-16  4       21   7
# 2020-03-17  1       36  12
# 2020-03-18  2       24   8
# 2020-03-19  3       42  13
# 2020-03-20  4       63  20
# 2020-03-21  1       57  18
# 2020-03-22  2       54  17
# 2020-03-23  3       69  22
# 2020-03-24  4       57  18
# 2020-03-25  1      117  38
# 2020-03-26  2      114  37
# 2020-03-27  3       96  31
# 2020-03-28  4      171  55
# 2020-03-29  1      138  44
# 2020-03-30  2      174  56
# 2020-03-31  3      132  42
# 2020-04-01  4      171  55
# 2020-04-02  1      180  58
# 2020-04-03  2      171  55
# 2020-04-04  3      166  53
# 2020-04-05  4      150  48
# 2020-04-06  1      150  48
# ...

# %%
print("Death per note: %s" % round(df_g['entries'].max() / 15))
# Out:
# Death per note: 21

# %% [markdown]
# ## Definition for the music
# * 1 day = 3mm (= 1bar)
# * 1 note = max 21 death

# %% [markdown]
# ## Go detail

# %%
pd.set_option('display.max_rows', 200)
d = df_g[(df_g.index >= '2021-01-01') & (df_g.index <= '2021-02-31')]
d['entries'].plot.bar(figsize=(15, 3))
# Out:
# <AxesSubplot:xlabel='datum'>

# %%
d.sort_values('entries', ascending=False).head()
# Out:
#             b  entries    %
# datum
# 2020-11-18  3      312  100
# 2020-11-12  1      307   98
# 2020-12-20  3      294   94
# 2020-12-14  1      291   93
# 2020-11-23  4      286   92

# %%
d['entries'].plot(figsize=(15, 3))
# Out:
# <AxesSubplot:xlabel='datum'>

# %%
d
# Out:
#             b  entries   %
# datum
# 2020-04-17  4      108  35
# 2020-04-18  1      102  33
# 2020-04-19  2       63  20
# 2020-04-20  3      114  37
# 2020-04-21  4       99  32
# 2020-04-22  1       81  26
# 2020-04-23  2       93  30
# 2020-04-24  3       81  26
# 2020-04-25  4       75  24
# 2020-04-26  1       39  13
# 2020-04-27  2       69  22
# 2020-04-28  3       36  12
# 2020-04-29  4       33  11
# 2020-04-30  1       42  13
# 2020-05-01  2       36  12
# 2020-05-02  3       27   9
# 2020-05-03  4       24   8
# 2020-05-04  1       27   9
# 2020-05-05  2       30  10
# 2020-05-06  3       12   4
# 2020-05-07  4       36  12
# 2020-05-08  1       21   7
# 2020-05-09  2       15   5
# 2020-05-10  3       21   7
# 2020-05-11  4        9   3
# 2020-05-12  1        3   1
# 2020-05-13  2        3   1
# 2020-05-14  3        6   2
# 2020-05-15  4       15   5
# 2020-05-16  1        3   1
# 2020-05-17  2       12   4
# 2020-05-18  3        9   3
# 2020-05-19  4       12   4
# ...
